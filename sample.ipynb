# %%
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data="config.yaml", epochs=1)  # train the model
# Out:
# Ultralytics 8.3.104  Python-3.13.2 torch-2.6.0+cpu CPU (13th Gen Intel Core(TM) i7-13620H)
# ...

# %%
from IPython.display import Image, display

# Display a result image (adjust the filename if needed)
output_path = r"C:\Users\MSI\Documents\Thesis_Project\Automste_Testing_DeepSeek_Model\Fine-Tuning-Deep-Seek_R1\runs\detect\train4\val_batch0_labels.jpg"
display(Image(filename=output_path))
